# %%
# %run main.py --dataset "vkitti" --complexity "2D"
# Out:
# bbox;  tf.Tensor(
# [[0.22463769 0.3373591  0.5226667  0.752     ]
#  [0.6038647  0.7809984  0.47733334 0.848     ]
#  [0.57246375 0.67069244 0.47466666 0.6986667 ]
#  [0.30515298 0.37278584 0.5226667  0.68      ]
#  [0.5660225  0.626409   0.488      0.6346667 ]
#  [0.6239936  0.67069244 0.46666667 0.53066665]
#  [0.57568437 0.6779388  0.368      0.5226667 ]
#  [0.6980676  0.7648953  0.45066667 0.536     ]
#  [0.6827697  0.74959743 0.44533333 0.5226667 ]
#  [0.3510467  0.38808373 0.50666666 0.56266665]
#  [0.32125604 0.35909823 0.50666666 0.568     ]
#  [0.08937198 0.14251208 0.5466667  0.6106667 ]
#  [0.32206118 0.38566828 0.49066666 0.58133334]
#  [0.22463769 0.3373591  0.5226667  0.752     ]
#  [0.6038647  0.7809984  0.47733334 0.848     ]
#  [0.57246375 0.67069244 0.47466666 0.6986667 ]
#  [0.30515298 0.37278584 0.5226667  0.68      ]
#  [0.5660225  0.626409   0.488      0.6346667 ]
#  [0.6239936  0.67069244 0.46666667 0.53066665]
#  [0.57568437 0.6779388  0.368      0.5226667 ]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

log_data = pd.read_csv('train_log.csv')

print(log_data)
# Plot training & validation Mean Average Error for the bounding box
plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(log_data['epoch'], log_data['bbox_reshaped_mae'], label='Train')
plt.plot(log_data['epoch'], log_data['val_bbox_reshaped_mae'], label='Validation')
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 2, 2)
plt.plot(log_data['epoch'], log_data['loss'], label='Train')
plt.plot(log_data['epoch'], log_data['val_loss'], label='Validation')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper left')

# Plot training & validation accuracy for the labels 
plt.subplot(2, 2, 3)
plt.plot(log_data['epoch'], log_data['label_reshaped_binary_accuracy'], label='Train')
plt.plot(log_data['epoch'], log_data['val_label_reshaped_binary_accuracy'], label='Validation')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper left')

plt.show()
# Out:
#    epoch  bbox_reshaped_mae  label_reshaped_binary_accuracy      loss  \
# 0      0           0.150492                        0.602300  0.743061
# 1      1           0.085561                        0.730909  0.550259
# 2      0           0.146243                        0.556305  0.913786
# 3      0           0.104242                        0.551556  0.763818
#
#    val_bbox_reshaped_mae  val_label_reshaped_binary_accuracy  val_loss
# 0               0.094884                            0.876039  0.494444
# 1               0.075784                            0.924918  0.369416
# 2               0.138339                            0.817586  0.691535
# 3               0.068289                            0.830940  0.532149
